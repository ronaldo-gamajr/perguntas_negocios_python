# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldo-gamajr/perguntas_negocios_python/blob/main/manipulacao_arquivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manipulação de arquivos

# %%
lista_resumida = [
    "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.",
    "It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus"
]

# %%
with open("lista-resumos.txt", "w", encoding="utf-8") as arquivo:
  for resumo in lista_resumida:
    arquivo.write(f"{resumo}\n")

# %%
# Abrindo um arquivo

f = open("lista-resumos.txt")
print(f.read())
f.close() # usado para fechar o arquivo
# Out:
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus

# %%
# Lendo apenas partes do arquivo
# Retornando os 11 primeiros caracteres
with open("lista-resumos.txt") as arquivo:
  print(arquivo.read(11))
# Out:
# Lorem Ipsum

# %%
# Ler uma linha do arquivo
with open("lista-resumos.txt") as arquivo:
  print(arquivo.readline())
# Out:
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.

# %%
# Ler duas linha do arquivo
with open("lista-resumos.txt") as arquivo:
  print(arquivo.readline())
  print(arquivo.readline())
# Out:
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
#
# It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus

# %%
# Percorrendo linha por linha
with open("lista-resumos.txt") as f:
  for x in f:
    print(x)
# Out:
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
#
# It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus

# %% [markdown]
# ### Escrita de Arquivo

# %%
# Gravar um arquivo existente
with open("lista-resumos.txt", "a") as f:
  f.write("Linha nova adicionada")

  with open("lista-resumos.txt") as f:
    print(f.read())
# Out:
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus
# Now the file has more content!Now the file has more content!Linha nova adicionadaLinha nova adicionada

# %%
# Sobreescrevendo o conteúdo existente

with open("lista-resumos.txt", "w") as f:
  f.write("Sobrescrevendo o arquivo")

  with open("lista-resumos.txt") as f:
    print(f.read())

# %% [markdown]
# ### Criando novo ficheiro

# %%
f = open("novo-arquivo.txt", "x")

# %% [markdown]
# ### Excluindo arquivo

# %%
import os
if os.path.exists("novo-arquivo.txt"):
  os.remove("novo-arquivo.txt")
else:
  print("O arquivo não existe")
# Out:
# O arquivo não existe

# %% [markdown]
# ### Excluindo a pasta inteira

# %%
import os
os.rmdir("nome-da-pasta")
# remove somente pastas vazias.
