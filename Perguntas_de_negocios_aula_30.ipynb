# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldo-gamajr/perguntas_negocios_python/blob/main/Perguntas_de_negocios_aula_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando as Bibliotecas e carregando o Dataframe

# %%
import pandas as pd
import re
from google.colab import drive
#drive é um módulo da biblioteca Google Colab

drive.mount('/content/drive')

df_raw = pd.read_csv('/content/drive/MyDrive/FTC - Analise de Dados/train.csv')

df_raw.head()
# Out:
# Mounted at /content/drive
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
# ...

# %% [markdown]
# # Limpeza do Dataframe

# %%
# Fazendo uma cópia do dataframe lido
df = df_raw.copy()

# Remover espaço da string
for i in range(len(df)):
  df.loc[i, 'ID'] = df.loc[i, 'ID'].strip()
  df.loc[i, 'Delivery_person_ID'] = df.loc[i, 'Delivery_person_ID'].strip()

# Excluir as linhas com a idade dos entregadores vazia
linhas_vazias = df['Delivery_person_Age'] != 'NaN '
df = df.loc[linhas_vazias, :]

# Conversão de texto/categoria/string para numeros inteiros
df['Delivery_person_Age'] = df['Delivery_person_Age'].astype(int)

# Conversão de texto/categoria/string para numeros decimais
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].astype(float)

# Conversão de texto para data
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

# Removendo 'NaN ' da coluna multiple_deliveries e convertendo para numero inteiro
linhas_vazias = df['multiple_deliveries'] != 'NaN '
df = df.loc[linhas_vazias, :]
df['multiple_deliveries'] = df['multiple_deliveries'].astype(int)

# Remover o texto de numeros
df = df.reset_index( drop=True )
for i in range( len( df ) ):
    df.loc[i, 'Time_taken(min)'] = re.findall( r'\d+', df.loc[i, 'Time_taken(min)'] )
# Out:
# <ipython-input-2-36c14428114d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_person_Age'] = df['Delivery_person_Age'].astype(int)
# <ipython-input-2-36c14428114d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].astype(float)
# <ipython-input-2-36c14428114d>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %% [markdown]
# # Respondendo as perguntas de negócios

# %%
df1 = df.copy()
df1.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                      4.9
# 1  0xb379     BANGRES18DEL02                   34                      4.5
# 2  0x5d6d     BANGRES19DEL01                   23                      4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                      4.7
# 4  0x70a2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# 1. Qual o número total de entregas cadastrados na base de dados?

# %%
print(f'O número de entregas cadastradas é {df1.shape[0]}')
# Out:
# O número de entregas cadastradas é 42805

# %% [markdown]
# 2. Qual o número total de entregadores únicos cadastrados na base de dados?

# %%
print(f"O número de entregadores cadastrados é igual a {len(df1['Delivery_person_ID'].unique())}")
# Out:
# O número de entregadores cadastrados é igual a 1320

# %% [markdown]
# 3. Qual a idade do entregador mais velho? E do mais novo?

# %%
df1.sort_values('Delivery_person_Age', ascending=False)
# A maior idade é 50 e a menor é 15
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 30363  0xbf33      KNPRES03DEL03                   50
# 27254   0x404     CHENRES04DEL01                   50
# 35712   0x466     CHENRES14DEL02                   50
# 26636   0x3fd     BANGRES13DEL01                   50
# 9486    0x5b0      MYSRES04DEL01                   50
# ...       ...                ...                  ...
# 22286   0x3f7     CHENRES04DEL01                   15
# 22268  0x1ea0     BANGRES17DEL02                   15
# 21004   0x3ed   RANCHIRES09DEL01                   15
# 25517   0x3f2     BANGRES02DEL02                   15
# 31177   0x622     CHENRES03DEL02                   15
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 30363                      6.0           -26.469003            -80.316344
# 27254                      6.0           -13.029780            -80.208812
# 35712                      6.0            13.026279             80.174568
# ...

# %% [markdown]
# 4. Qual o ID do entregador com a maior idade? E o ID do entregaor com a menor idade?

# %%
maior_idade_id = df1.sort_values('Delivery_person_Age', ascending=False).iloc[0,1]
menor_idade_id = df1.sort_values('Delivery_person_Age', ascending=False).iloc[-1,1]
print(f"O ID do entregador com a maior idade é {maior_idade_id} e o de menor idade é {menor_idade_id}")
# Out:
# O ID do entregador com a maior idade é KNPRES03DEL03 e o de menor idade é CHENRES03DEL02

# %% [markdown]
# 5. Quais os nomes das condições climáticas?

# %%
df1['Weatherconditions'].unique()
# Out:
# array(['conditions Sunny', 'conditions Stormy', 'conditions Sandstorms',
#        'conditions Cloudy', 'conditions Fog', 'conditions Windy',
#        'conditions NaN'], dtype=object)

# %% [markdown]
# 6. Quantas entregas foram realizadas sob condições climáticas de tempestade de areia? ( Sandstorms )

# %%
condition = 'conditions Sandstorms'

filtro = df1['Weatherconditions'] == 'conditions Sandstorms'
len(df1.loc[filtro, :])
# Out:
# 7083

# %% [markdown]
# 7. Quais eram as condições climáticas da data mais recente de entrega?

# %%
df_aux = df1.sort_values('Order_Date', ascending = False)
df_aux.head()
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 21402  0x6eda      HYDRES12DEL02                   28
# 28110  0x1e0a      VADRES13DEL02                   32
# 10200  0xa54e      VADRES02DEL01                   20
# 15550  0x1bbf      MYSRES19DEL02                   32
# 27979  0x3a2a      MUMRES09DEL01                   24
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 21402                      4.7            17.429585             78.392621
# 28110                      4.7            22.310237             73.158921
# 10200                      4.9             0.000000              0.000000
# 15550                      4.0            12.334022             76.618203
# 27979                      4.6            18.994049             72.825203
#
#        Delivery_location_latitude  Delivery_location_longitude Order_Date  \
# 21402                   17.509585                    78.472621 2022-04-06
# ...

# %% [markdown]
# 8. Quantos tipos de densidade de trânsito existem na base de dados? Quais os nomes deles?

# %%
print(len(df1['Road_traffic_density'].unique()))
print(df1['Road_traffic_density'].unique())
# Out:
# 5
# ['High ' 'Jam ' 'Low ' 'Medium ' 'NaN ']

# %% [markdown]
# 9. Quantas entregas foram feitas em cada condição climática?

# %%
#colocar as condições únicas em uma lista
condicoes = list(df1['Weatherconditions'].unique())
condicoes
# Percorrer a lista com o FOR e contar as entregas em cada condição
for condicao in condicoes:
  print(f'A condição climática {condicao} teve {df1.loc[df1["Weatherconditions"] == condicao, :].shape[0]} entregas')
# Out:
# A condição climática conditions Sunny teve 6904 entregas
# A condição climática conditions Stormy teve 7226 entregas
# A condição climática conditions Sandstorms teve 7083 entregas
# A condição climática conditions Cloudy teve 7135 entregas
# A condição climática conditions Fog teve 7288 entregas
# A condição climática conditions Windy teve 7078 entregas
# A condição climática conditions NaN teve 91 entregas

# %% [markdown]
# 10. Quantos entregadores únicos fizeram entregas em cada condição climática?

# %%
condicoes = list(df1['Weatherconditions'].unique())
condicoes
for condicao in condicoes:
  qtd_entrega = len(df1.loc[df1['Weatherconditions'] == condicao, 'Delivery_person_ID'].unique())
  print(f'A condição climática {condicao} teve {qtd_entrega} entregadores únicos')
# Out:
# A condição climática conditions Sunny teve 1233 entregadores únicos
# A condição climática conditions Stormy teve 1234 entregadores únicos
# A condição climática conditions Sandstorms teve 1239 entregadores únicos
# A condição climática conditions Cloudy teve 1246 entregadores únicos
# A condição climática conditions Fog teve 1251 entregadores únicos
# A condição climática conditions Windy teve 1230 entregadores únicos
# A condição climática conditions NaN teve 87 entregadores únicos

# %% [markdown]
# 11. Quantas entregas foram feitas em cada tipo de densidade de trânsito?

# %%
condicoes = list(df1['Road_traffic_density'].unique())
condicoes
for condicao in condicoes:
  qtd_entrega = len(df1.loc[df1['Road_traffic_density'] == condicao, 'Delivery_person_ID'].unique())
  print(f'A condição climática {condicao} teve {qtd_entrega} entregas')
# Out:
# A condição climática High  teve 787 entregas
# A condição climática Jam  teve 1306 entregas
# A condição climática Low  teve 1310 entregas
# A condição climática Medium  teve 1287 entregas
# A condição climática NaN  teve 87 entregas

# %% [markdown]
# 12. Quantos entregadores únicos fizeram entregas em cada tipo de densidade de trânsito?

# %%
condicoes = list(df1['Road_traffic_density'].unique())
condicoes
for condicao in condicoes:
  qtd_entrega = len(df1.loc[df1['Road_traffic_density'] == condicao, 'Delivery_person_ID'].unique())
  print(f'A condição climática {condicao} teve {qtd_entrega} entregadores unicos')
# Out:
# A condição climática High  teve 787 entregadores unicos
# A condição climática Jam  teve 1306 entregadores unicos
# A condição climática Low  teve 1310 entregadores unicos
# A condição climática Medium  teve 1287 entregadores unicos
# A condição climática NaN  teve 87 entregadores unicos

# %% [markdown]
# 13. Quantas cidades únicas existem na base? Quais são os seus nomes?

# %%
print(len(df1['City'].unique()))
print(df1['City'].unique())
# Out:
# 4
# ['Urban ' 'Metropolitian ' 'Semi-Urban ' 'NaN ']

# %% [markdown]
# 14. Quantos tipos de veículos existem na base de dados?

# %%
print(len(df1['Type_of_vehicle'].unique()))
print(df1['Type_of_vehicle'].unique())
# Out:
# 4
# ['motorcycle ' 'scooter ' 'electric_scooter ' 'bicycle ']

# %% [markdown]
# 15. Qual tipo de veículo que mais fez entregas com a condição de trânsito pesado?

# %%
veiculos = list(df1['Type_of_vehicle'].unique())
total_entregas = 0
tipo_veiculos = ''
for veiculo in veiculos:
  filtro = (df1['Type_of_vehicle'] == veiculo) & (df1['Road_traffic_density'] == 'High ')
  aux = df1.loc[filtro, :].shape[0]
  if total_entregas < aux:
    total_entregas = aux
    tipo_veiculos = veiculo
print(f'{tipo_veiculos} -> {total_entregas}')
# Out:
# motorcycle  -> 2481
